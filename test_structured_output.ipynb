# %%
from openai import OpenAI
from pydantic import BaseModel
from langchain_openai import ChatOpenAI

client = ChatOpenAI(base_url="http://127.0.0.1:8081/v1", api_key="dummy", model='gpt-5')

# %%
class Step(BaseModel):
    explanation: str
    output: str

class MathSolution(BaseModel):
    steps: list[Step]
    final_answer: str


resp = await client.with_structured_output(MathSolution).ainvoke(
    "solve 8x + 7 = -23"
)


result = resp.choices[0].message.parsed
for i, step in enumerate(result.steps, 1):
    print(f"Step {i}: {step.explanation}")
    print(f"  → {step.output}\n")
print(f"Answer: {result.final_answer}")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 10
#       6     steps: list[Step]
#       7     final_answer: str
# ---> 10 resp = await client.with_structured_output(MathSolution).ainvoke(
#      11     [{"role": "user", "content": "solve 8x + 7 = -23"}]
#      12 )
#      15 result = resp.choices[0].message.parsed
#      16 for i, step in enumerate(result.steps, 1):
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:3197, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    3195             else:
#    3196                 part = functools.partial(step.ainvoke, input_, config)
# -> 3197             input_ = await coro_with_context(part(), context, create_task=True)
#    3198     # finish the root run
#    3199 except BaseException as e:
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:5708, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5701 @override
#    5702 async def ainvoke(
#    5703     self,
#    (...)   5706     **kwargs: Any | None,
#    5707 ) -> Output:
# -> 5708     return await self.bound.ainvoke(
#    5709         input,
#    5710         self._merge_configs(config),
#    5711         **{**self.kwargs, **kwargs},
#    5712     )
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:425, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     415 @override
#     416 async def ainvoke(
#     417     self,
#    (...)    422     **kwargs: Any,
#     423 ) -> AIMessage:
#     424     config = ensure_config(config)
# --> 425     llm_result = await self.agenerate_prompt(
#     426         [self._convert_input(input)],
#     427         stop=stop,
#     428         callbacks=config.get("callbacks"),
#     429         tags=config.get("tags"),
#     430         metadata=config.get("metadata"),
#     431         run_name=config.get("run_name"),
#     432         run_id=config.pop("run_id", None),
#     433         **kwargs,
#     434     )
#     435     return cast(
#     436         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     437     )
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1132, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1123 @override
#    1124 async def agenerate_prompt(
#    1125     self,
#    (...)   1129     **kwargs: Any,
#    1130 ) -> LLMResult:
#    1131     prompt_messages = [p.to_messages() for p in prompts]
# -> 1132     return await self.agenerate(
#    1133         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1134     )
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1090, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1077     if run_managers:
#    1078         await asyncio.gather(
#    1079             *[
#    1080                 run_manager.on_llm_end(
#    (...)   1088             ]
#    1089         )
# -> 1090     raise exceptions[0]
#    1091 flattened_outputs = [
#    1092     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[union-attr]
#    1093     for res in results
#    1094 ]
#    1095 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1359, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1357     result = generate_from_stream(iter(chunks))
#    1358 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 1359     result = await self._agenerate(
#    1360         messages, stop=stop, run_manager=run_manager, **kwargs
#    1361     )
#    1362 else:
#    1363     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1677, in BaseChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#    1675     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1676         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1677     raise e
#    1678 if (
#    1679     self.include_response_headers
#    1680     and raw_response is not None
#    1681     and hasattr(raw_response, "headers")
#    1682 ):
#    1683     generation_info = {"headers": dict(raw_response.headers)}
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1641, in BaseChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#    1637     payload.pop("stream")
#    1638     raw_response = await self.root_async_client.chat.completions.with_raw_response.parse(  # noqa: E501
#    1639         **payload
#    1640     )
# -> 1641     response = raw_response.parse()
#    1642 elif self._use_responses_api(payload):
#    1643     original_schema_obj = kwargs.get("response_format")
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/openai/_legacy_response.py:139, in LegacyAPIResponse.parse(self, to)
#     137 parsed = self._parse(to=to)
#     138 if is_given(self._options.post_parser):
# --> 139     parsed = self._options.post_parser(parsed)
#     141 if isinstance(parsed, BaseModel):
#     142     add_request_id(parsed, self.request_id)
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1662, in AsyncCompletions.parse.<locals>.parser(raw_completion)
#    1661 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
# -> 1662     return _parse_chat_completion(
#    1663         response_format=response_format,
#    1664         chat_completion=raw_completion,
#    1665         input_tools=tools,
#    1666     )
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/openai/lib/_parsing/_completions.py:146, in parse_chat_completion(response_format, input_tools, chat_completion)
#     136             else:
#     137                 tool_calls.append(tool_call)
#     139     choices.append(
#     140         construct_type_unchecked(
#     141             type_=ParsedChoice[ResponseFormatT],
#     142             value={
#     143                 **choice.to_dict(),
#     144                 "message": {
#     145                     **message.to_dict(),
# --> 146                     "parsed": maybe_parse_content(
#     147                         response_format=response_format,
#     148                         message=message,
#     149                     ),
#     150                     "tool_calls": tool_calls if tool_calls else None,
#     151                 },
#     152             },
#     153         )
#     154     )
#     156 return construct_type_unchecked(
#     157     type_=ParsedChatCompletion[ResponseFormatT],
#     158     value={
#    (...)    161     },
#     162 )
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/openai/lib/_parsing/_completions.py:196, in maybe_parse_content(response_format, message)
#     190 def maybe_parse_content(
#     191     *,
#     192     response_format: type[ResponseFormatT] | ResponseFormatParam | Omit,
#     193     message: ChatCompletionMessage | ParsedChatCompletionMessage[object],
#     194 ) -> ResponseFormatT | None:
#     195     if has_rich_response_format(response_format) and message.content and not message.refusal:
# --> 196         return _parse_content(response_format, message.content)
#     198     return None
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/openai/lib/_parsing/_completions.py:245, in _parse_content(response_format, content)
#     243 def _parse_content(response_format: type[ResponseFormatT], content: str) -> ResponseFormatT:
#     244     if is_basemodel_type(response_format):
# --> 245         return cast(ResponseFormatT, model_parse_json(response_format, content))
#     247     if is_dataclass_like_type(response_format):
#     248         if PYDANTIC_V1:
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/openai/_compat.py:171, in model_parse_json(model, data)
#     169 if PYDANTIC_V1:
#     170     return model.parse_raw(data)  # pyright: ignore[reportDeprecated]
# --> 171 return model.model_validate_json(data)
#
# File ~/dev/private/ChatMock-FastAPI/.venv/lib/python3.13/site-packages/pydantic/main.py:766, in BaseModel.model_validate_json(cls, json_data, strict, extra, context, by_alias, by_name)
#     760 if by_alias is False and by_name is not True:
#     761     raise PydanticUserError(
#     762         'At least one of `by_alias` or `by_name` must be set to True.',
#     763         code='validate-by-alias-and-name-false',
#     764     )
# --> 766 return cls.__pydantic_validator__.validate_json(
#     767     json_data, strict=strict, extra=extra, context=context, by_alias=by_alias, by_name=by_name
#     768 )
#
# ValidationError: 1 validation error for MathSolution
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='<think>**Solving a linea...= -30/8 = -15/4 = -3.75', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
